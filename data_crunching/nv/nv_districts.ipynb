# %%
import geopandas as gpd

# %%
geojson_path = "2021Congressional_Final_SB1_Amd2.geojson"
gdf = gpd.read_file(geojson_path)

# %%
gdf.columns
# Out:
# Index(['DISTRICT', 'DIST_NAME', 'Area_Sq_Mi', 'Perim_Mi', 'Shape_Leng',
#        'Shape_Area', 'geometry'],
#       dtype='object')

# %%
gdf
# Out:
#    DISTRICT DIST_NAME    Area_Sq_Mi     Perim_Mi  Shape_Leng  Shape_Area  \
# 0       1.0         1   1018.893144   173.068667    2.785004    0.263286
# 1       2.0         2  65518.254431  1189.758384   20.109243   18.023403
# 2       3.0         3   2024.758100   317.772481    5.105628    0.522275
# 3       4.0         4  42008.859287  1025.527893   16.980138   11.131046
#
#                                             geometry
# 0  POLYGON ((-115.18088 36.08599, -115.18112 36.0...
# 1  POLYGON ((-119.84379 38.89173, -119.84426 38.8...
# 2  POLYGON ((-114.63349 35.00186, -114.63361 35.0...
# 3  POLYGON ((-117.17724 39.16327, -117.12592 39.1...

# %%
import pandas as pd
import json

with open('nv_racial_data.json', 'r') as f:
    nv_racial_data = json.load(f)

df_nv_racial = pd.json_normalize(nv_racial_data)

# %%
df_nv_racial
# Out:
#    district  2020_population  white.population  white.percent  \
# 0         1           776153            354538         0.4568
# 1         2           776154            525157         0.6766
# 2         3           776153            373902         0.4817
# 3         4           776154            334866         0.4314
#
#    black.population  black.percent  american_indian.population  \
# 0            100814         0.1299                       23644
# 1             25210         0.0325                       38061
# 2             98120         0.1264                       18587
# 3            151054         0.1946                       25498
#
#    american_indian.percent  asian.population  asian.percent  \
# 0                   0.0305             79806         0.1028
# 1                   0.0490             48366         0.0623
# 2                   0.0239            163953         0.2112
# 3                   0.0329             61468         0.0792
#
# ...

# %%
gdf_merged = gdf.merge(df_nv_racial, left_on='DIST_NAME', right_on='district', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22260\483790354.py in ?()
# ----> 1 gdf_merged = gdf.merge(df_nv_racial, left_on='dist_name', right_on='district', how='left')
#
# c:\Users\ultra\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# ...
